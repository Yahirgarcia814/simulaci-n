# %% [markdown]
# Steven Yahir García Galvan
#
# 29/08/2024
#
# visualizacion

# %% [markdown]
# ## Graficar las siguientes funciones f(x). Determina el dominio a partir de la función:

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.linspace(-3,3,100)
y= x**2-4*x+2
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.linspace(-3,3,100)
y= np.sin(3*x)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.linspace(-3,3,100)
y= np.exp(2*x)-3
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.linspace(-3,3,100)
y= np.sqrt(x**2 - 4)
plt.plot(x,y)
# Out:
# C:\Users\Yahir Garcìa\AppData\Local\Temp\ipykernel_3708\2154432872.py:4: RuntimeWarning: invalid value encountered in sqrt
#   y= np.sqrt(x**2 - 4)

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.linspace(-3,3,100)
y= np.cos(x + np.pi/4)
plt.plot(x,y)

# %% [markdown]
# ## Graficar los siguientes grupos de funciones:

# %%
import matplotlib.pyplot as plt
import numpy as np
x1= np.linspace(-3,3,100)
x2= np.linspace(-3,3,100)
x3= np.linspace(-3,3,100)

y1= 2*x + 1
y2= -x + 4
y3= x**2

plt.plot(x1,y1)
plt.plot(x2,y2)
plt.plot(x3,y3)

# %%
import matplotlib.pyplot as plt
import numpy as np
x1= np.linspace(-3,3,100)
x2= np.linspace(-3,3,100)

y1= np.sin(x)
y2= np.cos(x)

plt.plot(x1,y1)
plt.plot(x2,y2)
